# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
bikes = pd.read_csv('day.csv')

bikesDate = bikes[["dteday"]]
bikesDate["dteday"] = pd.to_datetime(bikesDate["dteday"])
bikesDate = bikesDate["dteday"].dt.month

bikecnt = bikes.cnt
bikeWeather = bikes.weathersit

(bikes.cnt).describe()
# Out:
# C:\Users\hocke\AppData\Local\Temp\ipykernel_20876\2514908479.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikesDate["dteday"] = pd.to_datetime(bikesDate["dteday"])
# count     731.000000
# mean     4504.348837
# std      1937.211452
# min        22.000000
# 25%      3152.000000
# 50%      4548.000000
# 75%      5956.000000
# max      8714.000000
# Name: cnt, dtype: float64

# %%
winter1 = pd.read_csv('day.csv', skiprows=range(61,732))
w1date = winter1[["dteday"]]
w1date["dteday"] = pd.to_datetime(w1date["dteday"])
w1date = w1date["dteday"].dt.day
w1cnt = winter1.cnt
# Out:
# C:\Users\hocke\AppData\Local\Temp\ipykernel_20876\1565935571.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w1date["dteday"] = pd.to_datetime(w1date["dteday"])

# %%
spring1 = pd.read_csv('day.csv', skiprows=([i for i in range(1, 60)] + [j for j in range(151, 732)]))
s1date = spring1[["dteday"]]
s1date["dteday"] = pd.to_datetime(s1date["dteday"])
s1date = s1date["dteday"].dt.month
s1cnt = spring1.cnt
# Out:
# C:\Users\hocke\AppData\Local\Temp\ipykernel_20876\1396992738.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s1date["dteday"] = pd.to_datetime(s1date["dteday"])

# %%
summer1 = pd.read_csv('day.csv', skiprows=([i for i in range(1, 151)] + [j for j in range(243, 730)]))
su1date = summer1[["dteday"]]
su1date["dteday"] = pd.to_datetime(su1date["dteday"])
su1date = su1date["dteday"].dt.month
su1cnt = summer1.cnt
# Out:
# C:\Users\hocke\AppData\Local\Temp\ipykernel_20876\2159355969.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   su1date["dteday"] = pd.to_datetime(su1date["dteday"])

# %%
fall1 = pd.read_csv('day.csv', skiprows=([i for i in range(1, 243)] + [j for j in range(334, 730)]))

f1cnt = fall1.cnt.mean()

# %%
winter2 = pd.read_csv('day.csv', skiprows=([i for i in range(1, 334)] + [j for j in range(425, 730)]))

w2cnt = winter2.cnt.mean()

# %%
spring2 = pd.read_csv('day.csv', skiprows=([i for i in range(1, 425)] + [j for j in range(517, 730)]))

s2cnt = spring2.cnt.mean()

# %%
summer2 = pd.read_csv('day.csv', skiprows=([i for i in range(1, 517)] + [j for j in range(609, 730)]))

su2cnt = summer2.cnt.mean()

# %%
fall2 = pd.read_csv('day.csv', skiprows=([i for i in range(1, 609)] + [j for j in range(700, 730)]))

f2cnt = fall2.cnt.mean()

# %%
winter3 = pd.read_csv('day.csv', skiprows=range(1, 700))

w3cnt = winter3.cnt.mean()

# %%
# %matplotlib inline

histogram = spring1.cnt.hist()

# %%
winter1.cnt.mean()
# Out:
# 1470.9166666666667

# %%
xa = bikesDate
ya = bikes.cnt
linear_regression = stats.linregress(xa,ya)
sns.set_style('whitegrid')
axes = sns.regplot(xa,ya)
y_label = axes.set_ylabel('Total Count of Rental Bikes')
x_label = axes.set_xlabel('Month')

print(linear_regression.slope)
print(linear_regression.intercept)
# Out:
# C:\Users\hocke\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 157.1229927895806
# 3479.9327173253887

# %%
xb = bikeWeather
yb = bikecnt
linear_regression = stats.linregress(xb,yb)
sns.set_style('whitegrid')
axes = sns.regplot(xb,yb)
y_label = axes.set_ylabel('Total Count of Rental Bikes')
x_label = axes.set_xlabel('Weather')
axes.set_xlim(0,4)

print(linear_regression.slope)
print(linear_regression.intercept)
# Out:
# -1057.2870171673808
# 5979.633047210299

# %%
fall1.cnt.hist()
# Out:
# <AxesSubplot:>
